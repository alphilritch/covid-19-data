# %%
import pandas as pd
import numpy as np

# %%
import os
current_path = os.getcwd()

# %%
current_path
# Out:
# '/Users/alphilritch/covid-19-data/live'

# %%
data = pd.read_csv("us-states.csv")

# %%
data[data['state'] == 'Alabama']
# Out:
#          date    state  fips   cases  deaths  confirmed_cases  \
# 0  2021-05-03  Alabama     1  528597   10913         408901.0
#
#    confirmed_deaths  probable_cases  probable_deaths
# 0            8602.0        119696.0           2311.0

# %%
data = pd.read_csv('/Users/alphilritch/covid-19-data/live/us-states.csv')

# %%
data
# Out:
#           date                     state  fips    cases  deaths  \
# 0   2021-05-03                   Alabama     1   528597   10913
# 1   2021-05-03                    Alaska     2    67598     330
# 2   2021-05-03                   Arizona     4   863927   17344
# 3   2021-05-03                  Arkansas     5   335968    5741
# 4   2021-05-03                California     6  3745021   61895
# 5   2021-05-03                  Colorado     8   516337    6438
# 6   2021-05-03               Connecticut     9   339233    8097
# 7   2021-05-03                  Delaware    10   104909    1626
# 8   2021-05-03      District of Columbia    11    47855    1106
# 9   2021-05-03                   Florida    12  2242770   35267
# 10  2021-05-03                   Georgia    13  1078321   19586
# 11  2021-05-03                      Guam    66     8944     137
# 12  2021-05-03                    Hawaii    15    32989     480
# 13  2021-05-03                     Idaho    16   187728    2048
# ...
